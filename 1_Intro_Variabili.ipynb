# %% [markdown]
# <a href="https://colab.research.google.com/github/bzznrc/Python-101/blob/master/1_Intro_Variabili.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algorithm
# *An algorithm is an unambiguous step-by-step procedure that takes an input instance (of the given problem) as input(s) and produces output for the problem instance*
# > L’implementazione di un algoritmo in un linguaggio di programmazione é quello che chiamiamo "programma"

# %% [markdown]
# ![00081.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Program
# Programming a computer to solve a problem always requires defining **data** to represent the things in your problem; this is called modeling. It also requires explaining **unambiguously** what process to follow in order to solve the problem.
#
# In Imperative programming (ours and the most well-known), we tell the computer what to do to the data. The computer starts out with its memory containing stuff, we tell it how to change that stuff, and it makes those changes.
#
# A program is ran, **one line at a time, from top to bottom**.
#
# Usually you can identify:
#
# > **Inputs** - Amount in Lire / Letters for Stickman
#
# > **Logic** - Calculating conversion / Checking if you guessed the word
#
# > **Outputs** - Euro value / Whether you've won or lost

# %%
### 1 - INPUT - Asking for data
lire = input("Inserisci LIRE: ")  

### 2 - LOGIC (is usually quite longer)
eur = float (lire) /1936.27

### 3 - OUTPUT - Communicating the result
print("EUR:", eur)

# %% [markdown]
# # Python
#
# *Python is an interpreted, high-level and general-purpose programming language.*
#
# *Python's design philosophy emphasizes code readability with its notable use of significant whitespace*
#
# Esistono due approcci sostanzialmente diversi alla programmazione in Python:
# > **File .py** - Codice scritto usando un **IDE** (tipo Visual Studio Code, da installare) ed eseguito da un **interprete python** (da installare). Avviene tutto in locale. É il modo "classico" di programmare in python.
#
# > **Online notebooks** - File .ipynb (come questo) che contengono sia codice che testo. Il codice viene eseguito su un server in cloud giá configurati. Comodo perché sul tuo PC non devi installare niente. Si usa a scopo didattico/dimostrativo e per qualche motivo non ancora chiarissimo anche nel magico mondo dell'AI.

# %% [markdown]
# # Note sulla Prospettiva
# Non ve lo aspettavate eh.
#
# Tradizionalmente il ruolo di chi scrive il programma (programmatore) e di chi lo usa (utente) é distinto, e l'utente non ha **mai** accesso al codice, né puó modificarlo in alcun modo.
#
# Lavorare su notebook (come questo) fa cadere in parte questo concetto, e difatti puó sembrare strano chiedere all'utente un valore quando possiamo direttamente inserirlo "manualmente" nel codice. Dobbiamo sempre tenere a mente che cercheremo di mantenere i due ruoli distinti (scriveremo il codice come programmatori, lo testeremo come utenti)

# %% [markdown]
# # IDEs & Reading Code
#
# A Python (.py) file is essentially text. You can actually change its extension to .txt and it will open to display the code as text.
#
# We don't code with text files and notepads, we use IDEs (Integrated Development Environments, like Visual Studio Code). An IDE is basically a notepad on sterodids, it allows us to write code and gives us all sorts of tools to check it and test it.
#
# An important thing -which might seem silly- is that it actually color-codes every word for us, based on its meaning. Let's see some examples.

# %%
#GREEN - Comment. This is a special line that gets ignored from the interpreter. It is used to write down whatever note you want
a = 2 #WHITE - Variables and numeric values. We'll see what they are
b = 'ciao' #ORANGE - Text values, called "Strings". They have to be surrounded by quotes (or double quotes)
c = True #BLUE - Boolean values. They can be True/False. We'll use them to write our logics
print('Non ci sto capendo granché') # YELLOW - Functions. They call other chunks of code to do some stuff for us. We'll see a few
for i in range(5) : pass #PURPLE - Statements (if, while, for...). They are used to control how code flows
d = int (input("Inserici numero: ")) / 2 #BLUE/GREEN - Casts.

# %% [markdown]
# # Print
# Cominciamo a vedere un po' di sintassi.
#
# Print scrive una stringa di testo (cioé il testo arancione delimitato dagli apici) in output
#
# Print puó scrivere tutto il testo che gli passiamo (direttamente o attraverso variabili). Ogni elemento deve essere separato da virgole

# %%
print('posso scrivere quello che voglio')

# %%
var_1 = 'Eheh ciao'
print("La mia variabile contiene ", var_1)
print("La mia variabile contiene ", var_1, " y'all")

# %%
#Divertiti scrivendo print che stampano robe a caso qui sotto!

# %% [markdown]
# #Variabili e Operazioni
# -Le variabili sono contenitori. Posso "mettere dentro" (cioé "assegnare") ad una variabile sia un valore numerico che una stringa, che deve sempre essere indicata con gli apici.
#
# -Ad una variabile che contiene un valore (a = 2) posso assegnare un altro valore, anche di tipo diverso (a = 'sushi'). Da quel punto in poi il valore di a sará 'sushi'.
#
# -Posso assegnare ad una variabile il risultato di un'operazione matematica (tra costanti o che include ***essa stessa*** variabili)

# %%
#Spiegone: stampo il testo "a vale: " e poi a seguire stampo 
#ció che é contenuto nella variabile che si chiama 'a', cioé il valore 2
a = 2
print('a vale: ', a)
b = 5
print('b vale: ', b)

# %%
#La variabile c viene creata (perché a questo punto non esiste ancora) 
#e il suo valore diventa la somma dei valori contenuti in a e b
c = a + b
print('c vale: ', c)

# %%
#La variabile a esiste giá. Il suo valore 
#viene sostituito con il suo valore moltiplicato per due
a = a * 2
print('a (moltiplicato): ', a)

# %%
#Una variabile puó contenere numeri ma anche testo. Python non fa una piega
a = 'sushi'
print('a (stringa): ', a)

# %%
#Si possono fare cose divertenti tipo moltiplicare testo per numeri
a = a * 2
print('a (stringa moltiplicata):  ', a)
b = 'tempura'
print('b (stringa): ', b)

# %%
#E sommare due variabili che contengono testo. 
#Posso anche moltiplicare una variabile testuale per 4 e sommarla ad un'altra
#Difficile che una cosa del genere torni mai utile, but still
c = a + b * 4
print('c (stringa moltiplicata):  ', c)

# %% [markdown]
# #Inputs
# La funzione input ferma l'esecuzione del programma e aspetta che l'utente inserisca un valore. Questo valore é poi assegnabile ad una variabile (in questo caso, viene assegnato alla variabile "nome")

# %%
nome = "boh"
print("Il nome ", nome, "fa un po' cagare")

# %%
#La variabile 'nome' contiene a questo punto il valore "boh"
#Questo valore verrá sostituito da quello che l'utente immetterá. 
#A questo punto il nuovo valore verrá stampato all'interno della print successiva
nome = input("Mi dici un nome bello?")
print("Il nome ", nome, "é molto piú bello!")

# %% [markdown]
# #Cast
# Lavorando con la funzione input() incontreremo presto un problema abbastanza spiacevole.
# Nel primo esempio qua sotto, chiedo un numero all'utente (le lire) e cerco di calcolare gli euro, dividendo per 1936.27.
#
# L'errore deriva dal fatto che, di default, input() restituisce **testo**.
# Se, ad esempio io inserisco 40000 (quarantamila lire), quello che finirá nella variabile lire sará "40000". Ovvero una stringa di testo che contiene il valore testuale "40000". A questo punto cercheró di dividere un testo per 1936.27, cosa che genererá l'errore.
#
# La funzione **float()** serve a dire a Python che il valore che l'utente ha inserito é da considerarsi come un numero con la virgola, invece che come una stringa di testo.
# Posso fare la stessa cosa trasformando la variabile in un numero intero con la funzione **int()**.

# %%
#Errore
#Variabile testuale: "40000"
#Variabile numerica: 40000
lire = input("Inserisci LIRE: ")
eur = lire / 1936.27
print("EUR:", eur)

# %%
#No errore
lire = input("Inserisci LIRE: ")
eur = float (lire) /1936.27
print("EUR:", eur)

# %% [markdown]
# # ES. 1 - EASY
# Crea una variabile (chiamala come vuoi) e assegnale la stringa "Bazza é un genio", poi scrivila in output

# %% [markdown]
# # ES. 2 - MEDIUM
# Scrivi in output la stringa precedente 100 volte, in modo astuto se possibile (spoiler: é possibile)

# %% [markdown]
# # ES. 3 - LEEEEROOOOOYYYYYY JEEEEEENKINS
# -Chiedi all'utente di scrivere una stringa e salvala in una variabile
#
# -Chiedi all'utente di scrivere un numero e salvalo in una variabile
#
# -Stampa in output la stringa scelta tante volte quanto specificato dal numero

# %% [markdown]
# # HW. 1
# -Chiedi all'utente due numeri, che rappresentano base ed altezza di un rettangolo
# -Comunica all'utente perimetro ed area del rettangolo
#
# -*Hints: potete usare tutte le variabili che volete* / *vi servirá un cast dell'input a float (vedi pt.4 - Euroconvertitore)*

# %%
## Qui raccogliamo gli inputs (INPUT)


## Qui facciamo i nostri conti (LOGICA)


## Qui comunichiamo il risultato all'utente (OUTPUT)
